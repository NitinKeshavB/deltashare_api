# %%
import requests
import os
import json
import base64
from dotenv import load_dotenv
from rich import print

# Read environment variables from .env file
load_dotenv()

client_id = os.getenv("CLIENT_ID")
client_secret = os.getenv("CLIENT_SECRET")
account_id = os.getenv("ACCOUNT_ID")


url = f"https://accounts.azuredatabricks.net/oidc/accounts/{account_id}/v1/token"

# Use form data instead of string payload
payload = {"grant_type": "client_credentials", "scope": "all-apis"}

# Encode credentials for Basic authentication
credentials = f"{client_id}:{client_secret}"
encoded_credentials = base64.b64encode(credentials.encode()).decode()

headers = {"Authorization": f"Basic {encoded_credentials}"}

# Send as form data (requests will automatically set Content-Type to application/x-www-form-urlencoded)
response = requests.post(url, headers=headers, data=payload)


# Extract the token from the response
if response.status_code == 200:
    try:
        token_data = response.json()
        created_at_utc = token_data.get("created_at")  # Assuming created_at is already in UTC format
        access_token = token_data.get("access_token")
        token_expiry = token_data.get("expires_in")
        print(f"\nAccess Token: {access_token}")
        print(f"Token Expiry (seconds): {token_expiry}")
        print(f"Token Created At (UTC): {token_data}")

        # Optionally save token to environment or file
        # os.environ['DATABRICKS_TOKEN'] = access_token
    except json.JSONDecodeError as e:
        print(f"\nJSON Decode Error: {e}")
        print(f"Raw response: {response.text}")  # First 500 chars
else:
    print(f"\nError: {response.status_code}")
    print(f"Response: {response.text}")  # First 500 chars
# Out:
# Access Token:
# eyJraWQiOiJjMGQ2YzQ2MTA4NWVmY2E1YTgzYTMxNzI2ZDQ2ZmMzN2QxNmMwYzY4NWQwNDRhMTJhNTUxNjhhOGM3MzZkM2U2IiwidHlwIjoiYXQrand
# 0IiwiYWxnIjoiUlMyNTYifQ.eyJjbGllbnRfaWQiOiJlMDQwNThlYy04MjY0LTQ0MGQtYTQ5ZC0yNWIzMWFjMWI5Y2EiLCJzY29wZSI6ImFsbC1hcGl
# zIiwiaWRtIjoiQ0FFUUFRPT0iLCJpc3MiOiJodHRwczovL2FjY291bnRzLmF6dXJlZGF0YWJyaWNrcy5uZXQvb2lkYy9hY2NvdW50cy81ZDdlMjI4My
# 1hYTIyLTQ3ZGMtOWNiMi1iYzUyMjE2YmUxZTkiLCJhdWQiOiI1ZDdlMjI4My1hYTIyLTQ3ZGMtOWNiMi1iYzUyMjE2YmUxZTkiLCJzdWIiOiJlMDQwN
# ThlYy04MjY0LTQ0MGQtYTQ5ZC0yNWIzMWFjMWI5Y2EiLCJpYXQiOjE3NjU4Mzg2MDQsImV4cCI6MTc2NTg0MjIwNCwianRpIjoiNWQ3ZjkyODktZDZh
# Mi00OGIxLWE1ZjMtMTAxYTAzZmUyMGFkIn0.aySY7fAcZG6R-cjrbRdULJxsVa7U6TpeV8U78dcPpTNCbR90msjxKw35xfhsVXD57fuuuT6spBxf_3m
# lCeHD1gbUDVsdafrQz3OI7wPYMMEJBSLuAbXr1EgdD4PSRVPPOObzauKQrrPjs9qAlsmEHxb3RfXlv5A6VouYP7yBZl9YZ0y8fOJ5FrvgE_C_M97t_B
# IOlIozA8zP4wHYcrDyLSv35W-70DnV8LwHnbMzSHfORZ1DnV8-PnrTvyPa5YzInNlbNbGbMYsOOdZrS3dJeiMnkoLwIM5g_-nxDDZ507ssebVyBwgV8
# 8TFs1CqUmlLFBjJEenRg_BTNgOJzkHdNg
# Token Expiry (seconds): 3600
# Token Created At (UTC): {'access_token':
# 'eyJraWQiOiJjMGQ2YzQ2MTA4NWVmY2E1YTgzYTMxNzI2ZDQ2ZmMzN2QxNmMwYzY4NWQwNDRhMTJhNTUxNjhhOGM3MzZkM2U2IiwidHlwIjoiYXQran
# d0IiwiYWxnIjoiUlMyNTYifQ.eyJjbGllbnRfaWQiOiJlMDQwNThlYy04MjY0LTQ0MGQtYTQ5ZC0yNWIzMWFjMWI5Y2EiLCJzY29wZSI6ImFsbC1hcG
# lzIiwiaWRtIjoiQ0FFUUFRPT0iLCJpc3MiOiJodHRwczovL2FjY291bnRzLmF6dXJlZGF0YWJyaWNrcy5uZXQvb2lkYy9hY2NvdW50cy81ZDdlMjI4M
# y1hYTIyLTQ3ZGMtOWNiMi1iYzUyMjE2YmUxZTkiLCJhdWQiOiI1ZDdlMjI4My1hYTIyLTQ3ZGMtOWNiMi1iYzUyMjE2YmUxZTkiLCJzdWIiOiJlMDQw
# NThlYy04MjY0LTQ0MGQtYTQ5ZC0yNWIzMWFjMWI5Y2EiLCJpYXQiOjE3NjU4Mzg2MDQsImV4cCI6MTc2NTg0MjIwNCwianRpIjoiNWQ3ZjkyODktZDZ
# hMi00OGIxLWE1ZjMtMTAxYTAzZmUyMGFkIn0.aySY7fAcZG6R-cjrbRdULJxsVa7U6TpeV8U78dcPpTNCbR90msjxKw35xfhsVXD57fuuuT6spBxf_3
# mlCeHD1gbUDVsdafrQz3OI7wPYMMEJBSLuAbXr1EgdD4PSRVPPOObzauKQrrPjs9qAlsmEHxb3RfXlv5A6VouYP7yBZl9YZ0y8fOJ5FrvgE_C_M97t_
# BIOlIozA8zP4wHYcrDyLSv35W-70DnV8LwHnbMzSHfORZ1DnV8-PnrTvyPa5YzInNlbNbGbMYsOOdZrS3dJeiMnkoLwIM5g_-nxDDZ507ssebVyBwgV
# 88TFs1CqUmlLFBjJEenRg_BTNgOJzkHdNg', 'scope': 'all-apis', 'token_type': 'Bearer', 'expires_in': 3600}

# %%
from databricks.sdk import WorkspaceClient

w = WorkspaceClient(host="https://adb-1909534966707031.11.azuredatabricks.net/", token=access_token)

# List all recipients
all_recipients = w.recipients.list()

for recipient in all_recipients:
    print(recipient)
# Out:
# RecipientInfo(
#     activated=None,
#     activation_url=None,
#     authentication_type=<AuthenticationType.TOKEN: 'TOKEN'>,
#     cloud=None,
#     comment='aws_gmail_token',
#     created_at=1765439668687,
#     created_by='e04058ec-8264-440d-a49d-25b31ac1b9ca',
#     data_recipient_global_metastore_id=None,
#     expiration_time=None,
#     ip_access_list=None,
#     metastore_id=None,
#     name='aws_gmail_token',
#     owner='e04058ec-8264-440d-a49d-25b31ac1b9ca',
#     properties_kvpairs=SecurablePropertiesKvPairs(properties={'databricks.name': 'aws_gmail_token'}),
#     region=None,
#     sharing_code=None,
#     tokens=[],
#     updated_at=1765443251110,
#     updated_by='e04058ec-8264-440d-a49d-25b31ac1b9ca'
# )
# RecipientInfo(
#     activated=None,
#     activation_url=None,
#     authentication_type=<AuthenticationType.TOKEN: 'TOKEN'>,
#     cloud=None,
#     comment='aws_gmail_token',
#     created_at=1765439710347,
#     created_by='e04058ec-8264-440d-a49d-25b31ac1b9ca',
#     data_recipient_global_metastore_id=None,
#     expiration_time=None,
#     ip_access_list=IpAccessList(allowed_ip_addresses=['1.2.1.3/24']),
#     metastore_id=None,
#     name='aws_gmail_token_1',
#     owner='e04058ec-8264-440d-a49d-25b31ac1b9ca',
#     properties_kvpairs=SecurablePropertiesKvPairs(properties={'databricks.name': 'aws_gmail_token_1'}),
#     region=None,
#     sharing_code=None,
#     tokens=[
#         RecipientTokenInfo(
#             activation_url='https://australiaeast.azuredatabricks.net/delta_sharing/retrieve_config.html?73ED_z0KOm
# j0aUXJum_VphCC9XPi-b605btDvtXE3UDKHa50rvxb--zUU3l4JF3d',
#             created_at=1765439710353,
#             created_by='e04058ec-8264-440d-a49d-25b31ac1b9ca',
#             expiration_time=1773215710357,
#             id='3e22d25a-9abb-47a2-8525-190f7ef79910',
#             updated_at=1765439710357,
#             updated_by='e04058ec-8264-440d-a49d-25b31ac1b9ca'
#         )
#     ],
#     updated_at=1765439710347,
#     updated_by='e04058ec-8264-440d-a49d-25b31ac1b9ca'
# )
# RecipientInfo(
#     activated=None,
#     activation_url=None,
#     authentication_type=<AuthenticationType.TOKEN: 'TOKEN'>,
#     cloud=None,
#     comment='aws_gmail_token',
#     created_at=1765439738080,
#     created_by='e04058ec-8264-440d-a49d-25b31ac1b9ca',
#     data_recipient_global_metastore_id=None,
#     expiration_time=None,
#     ip_access_list=IpAccessList(allowed_ip_addresses=['1.2.1.3']),
#     metastore_id=None,
#     name='aws_gmail_token_2',
#     owner='e04058ec-8264-440d-a49d-25b31ac1b9ca',
#     properties_kvpairs=SecurablePropertiesKvPairs(properties={'databricks.name': 'aws_gmail_token_2'}),
#     region=None,
#     sharing_code=None,
#     tokens=[
#         RecipientTokenInfo(
#             activation_url='https://australiaeast.azuredatabricks.net/delta_sharing/retrieve_config.html?pSJ-KPJIed
# T6ODLx5r1Gq5sEfIHKMcFjwJXzJpdWkIpYdZmy-RbGXt1HQsCfiQhZ',
#             created_at=1765439983153,
#             created_by='e04058ec-8264-440d-a49d-25b31ac1b9ca',
#             expiration_time=1773215983155,
#             id='53771d64-6e54-4322-9cbd-227bdc49e78d',
#             updated_at=1765439983155,
#             updated_by='e04058ec-8264-440d-a49d-25b31ac1b9ca'
#         )
#     ],
#     updated_at=1765439738080,
#     updated_by='e04058ec-8264-440d-a49d-25b31ac1b9ca'
# )
# RecipientInfo(
#     activated=None,
#     activation_url=None,
#     authentication_type=<AuthenticationType.DATABRICKS: 'DATABRICKS'>,
#     cloud='aws',
#     comment=None,
#     created_at=1764726522964,
#     created_by='ntnkshv_edaas_outlook.com#ext#@ntnkshvedaasoutlook.onmicrosoft.com',
#     data_recipient_global_metastore_id='aws:us-east-2:7b2005d1-3c82-4382-88ac-6cf31fd84712',
#     expiration_time=None,
#     ip_access_list=None,
#     metastore_id='7b2005d1-3c82-4382-88ac-6cf31fd84712',
#     name='aws_jllt',
#     owner='ntnkshv_edaas_outlook.com#ext#@ntnkshvedaasoutlook.onmicrosoft.com',
#     properties_kvpairs=SecurablePropertiesKvPairs(
#         properties={
#             'databricks.name': 'aws_jllt',
#             'databricks.accountId': 'c4ad19ae-0bc4-42ef-bc39-d355bc959b98',
#             'databricks.metastoreId': '7b2005d1-3c82-4382-88ac-6cf31fd84712'
#         }
#     ),
#     region='us-east-2',
#     sharing_code=None,
#     tokens=[],
#     updated_at=1765432830586,
#     updated_by='ntnkshv_edaas_outlook.com#ext#@ntnkshvedaasoutlook.onmicrosoft.com'
# )
# RecipientInfo(
#     activated=None,
#     activation_url=None,
#     authentication_type=<AuthenticationType.DATABRICKS: 'DATABRICKS'>,
#     cloud='aws',
#     comment="' '",
#     created_at=1765439549582,
#     created_by='e04058ec-8264-440d-a49d-25b31ac1b9ca',
#     data_recipient_global_metastore_id='aws:us-west-2:d81ea1bd-b74b-4c76-bf14-2db1a74d1dd8',
#     expiration_time=None,
#     ip_access_list=None,
#     metastore_id='d81ea1bd-b74b-4c76-bf14-2db1a74d1dd8',
#     name='gmail_aws_1',
#     owner='e04058ec-8264-440d-a49d-25b31ac1b9ca',
#     properties_kvpairs=SecurablePropertiesKvPairs(
#         properties={
#             'databricks.name': 'gmail_aws_1',
#             'databricks.accountId': 'f0d84759-8340-47e3-9f95-0837b1eb3382',
#             'databricks.metastoreId': 'd81ea1bd-b74b-4c76-bf14-2db1a74d1dd8'
#         }
#     ),
#     region='us-west-2',
#     sharing_code=None,
#     tokens=[],
#     updated_at=1765442895573,
#     updated_by='e04058ec-8264-440d-a49d-25b31ac1b9ca'
# )
# RecipientInfo(
#     activated=None,
#     activation_url=None,
#     authentication_type=<AuthenticationType.TOKEN: 'TOKEN'>,
#     cloud=None,
#     comment='gmail_test_1',
#     created_at=1765234582815,
#     created_by='e04058ec-8264-440d-a49d-25b31ac1b9ca',
#     data_recipient_global_metastore_id=None,
#     expiration_time=None,
#     ip_access_list=IpAccessList(allowed_ip_addresses=['1.2.1.5/24']),
#     metastore_id=None,
#     name='gmail_test',
#     owner='e04058ec-8264-440d-a49d-25b31ac1b9ca',
#     properties_kvpairs=SecurablePropertiesKvPairs(properties={'databricks.name': 'gmail_test'}),
#     region=None,
#     sharing_code=None,
#     tokens=[],
#     updated_at=1765443771501,
#     updated_by='e04058ec-8264-440d-a49d-25b31ac1b9ca'
# )
# RecipientInfo(
#     activated=None,
#     activation_url=None,
#     authentication_type=<AuthenticationType.TOKEN: 'TOKEN'>,
#     cloud=None,
#     comment='gmail_test_1',
#     created_at=1765234628089,
#     created_by='e04058ec-8264-440d-a49d-25b31ac1b9ca',
#     data_recipient_global_metastore_id=None,
#     expiration_time=None,
#     ip_access_list=IpAccessList(allowed_ip_addresses=['1.2.3.1', '1.2.1.5/24']),
#     metastore_id=None,
#     name='gmail_test_1',
#     owner='e04058ec-8264-440d-a49d-25b31ac1b9ca',
#     properties_kvpairs=SecurablePropertiesKvPairs(properties={'databricks.name': 'gmail_test_1'}),
#     region=None,
#     sharing_code=None,
#     tokens=[
#         RecipientTokenInfo(
#             activation_url='https://australiaeast.azuredatabricks.net/delta_sharing/retrieve_config.html?45OBfPU1aM
# LVguY0h51FCm7Xah4IZBPn5PHKExO_c_Azt3TCvr_9BDNEVnbD_NvI',
#             created_at=1765234628097,
#             created_by='e04058ec-8264-440d-a49d-25b31ac1b9ca',
#             expiration_time=1773010628099,
#             id='fbf51d44-c588-473b-92f4-3f0b51d40659',
#             updated_at=1765234628099,
#             updated_by='e04058ec-8264-440d-a49d-25b31ac1b9ca'
#         )
#     ],
#     updated_at=1765441077163,
#     updated_by='e04058ec-8264-440d-a49d-25b31ac1b9ca'
# )
# RecipientInfo(
#     activated=None,
#     activation_url=None,
#     authentication_type=<AuthenticationType.TOKEN: 'TOKEN'>,
#     cloud=None,
#     comment='gmail_test_2',
#     created_at=1765234661618,
#     created_by='e04058ec-8264-440d-a49d-25b31ac1b9ca',
#     data_recipient_global_metastore_id=None,
#     expiration_time=None,
#     ip_access_list=IpAccessList(allowed_ip_addresses=['1.2.3.1/32']),
#     metastore_id=None,
#     name='gmail_test_2',
#     owner='e04058ec-8264-440d-a49d-25b31ac1b9ca',
#     properties_kvpairs=SecurablePropertiesKvPairs(properties={'databricks.name': 'gmail_test_2'}),
#     region=None,
#     sharing_code=None,
#     tokens=[
#         RecipientTokenInfo(
#             activation_url='https://australiaeast.azuredatabricks.net/delta_sharing/retrieve_config.html?OyHoqV9ZiU
# dVtkJd-0Xhlm4UaQBBKaRkBd5L1b4ex54lFvElhj91sh1joVhJPZhI',
#             created_at=1765234661625,
#             created_by='e04058ec-8264-440d-a49d-25b31ac1b9ca',
#             expiration_time=1773010661627,
#             id='9b96551f-3894-439e-9403-5409ad07a0ca',
#             updated_at=1765234661627,
#             updated_by='e04058ec-8264-440d-a49d-25b31ac1b9ca'
#         )
#     ],
#     updated_at=1765239095743,
#     updated_by='e04058ec-8264-440d-a49d-25b31ac1b9ca'
# )
# RecipientInfo(
#     activated=None,
#     activation_url=None,
#     authentication_type=<AuthenticationType.TOKEN: 'TOKEN'>,
#     cloud=None,
#     comment='gmail_test_5',
#     created_at=1765234997298,
#     created_by='e04058ec-8264-440d-a49d-25b31ac1b9ca',
#     data_recipient_global_metastore_id=None,
#     expiration_time=None,
#     ip_access_list=IpAccessList(allowed_ip_addresses=['1.2.3.1']),
#     metastore_id=None,
#     name='gmail_test_5',
#     owner='e04058ec-8264-440d-a49d-25b31ac1b9ca',
#     properties_kvpairs=SecurablePropertiesKvPairs(properties={'databricks.name': 'gmail_test_5'}),
#     region=None,
#     sharing_code=None,
#     tokens=[
#         RecipientTokenInfo(
#             activation_url='https://australiaeast.azuredatabricks.net/delta_sharing/retrieve_config.html?J5Sms0gzcp
# JlqdH4f3Ig2b757U6kr8sIziuYwtKk50HU8I0dH2niLZS1u1wPj4oT',
#             created_at=1765234997305,
#             created_by='e04058ec-8264-440d-a49d-25b31ac1b9ca',
#             expiration_time=1773010997308,
#             id='b6d276c4-da96-4f8a-b194-1d091b4706f0',
#             updated_at=1765234997308,
#             updated_by='e04058ec-8264-440d-a49d-25b31ac1b9ca'
#         )
#     ],
#     updated_at=1765234997298,
#     updated_by='e04058ec-8264-440d-a49d-25b31ac1b9ca'
# )
# RecipientInfo(
#     activated=None,
#     activation_url=None,
#     authentication_type=<AuthenticationType.TOKEN: 'TOKEN'>,
#     cloud=None,
#     comment='gmail_test_8',
#     created_at=1765235267803,
#     created_by='e04058ec-8264-440d-a49d-25b31ac1b9ca',
#     data_recipient_global_metastore_id=None,
#     expiration_time=None,
#     ip_access_list=None,
#     metastore_id=None,
#     name='gmail_test_8',
#     owner='account users',
#     properties_kvpairs=SecurablePropertiesKvPairs(properties={'databricks.name': 'gmail_test_8'}),
#     region=None,
#     sharing_code=None,
#     tokens=[
#         RecipientTokenInfo(
#             activation_url='https://australiaeast.azuredatabricks.net/delta_sharing/retrieve_config.html?wYD8fv0xgv
# sIeAPxtz6ox2ZBlBSvlxP9sMzbWxJ2LNsUSpD846GDxX-vCWag4vvm',
#             created_at=1765440910419,
#             created_by='e04058ec-8264-440d-a49d-25b31ac1b9ca',
#             expiration_time=1773216910420,
#             id='c415ad82-9951-47cf-a7bd-df0b77586737',
#             updated_at=1765440910420,
#             updated_by='e04058ec-8264-440d-a49d-25b31ac1b9ca'
#         )
#     ],
#     updated_at=1765440882352,
#     updated_by='ntnkshv_edaas_outlook.com#ext#@ntnkshvedaasoutlook.onmicrosoft.com'
# )
# RecipientInfo(
#     activated=None,
#     activation_url=None,
#     authentication_type=<AuthenticationType.TOKEN: 'TOKEN'>,
#     cloud=None,
#     comment='sdk-1764808574404699743',
#     created_at=1764805389927,
#     created_by='e04058ec-8264-440d-a49d-25b31ac1b9ca',
#     data_recipient_global_metastore_id=None,
#     expiration_time=None,
#     ip_access_list=IpAccessList(allowed_ip_addresses=['1.1.1.2/0']),
#     metastore_id=None,
#     name='pam-client-1764805388466627073',
#     owner='account users',
#     properties_kvpairs=SecurablePropertiesKvPairs(
#         properties={'databricks.name': 'pam-client-1764805388466627073'}
#     ),
#     region=None,
#     sharing_code=None,
#     tokens=[
#         RecipientTokenInfo(
#             activation_url='https://australiaeast.azuredatabricks.net/delta_sharing/retrieve_config.html?E63y2WWTvQ
# Gky8OCQS4eC7e8euDI6NEEKOsUuLLULjOhn13IuOSLDKES18zW0ThM',
#             created_at=1765440607181,
#             created_by='e04058ec-8264-440d-a49d-25b31ac1b9ca',
#             expiration_time=1773216607183,
#             id='77ac1af5-e862-4728-b88c-36cd93657359',
#             updated_at=1765440607183,
#             updated_by='e04058ec-8264-440d-a49d-25b31ac1b9ca'
#         )
#     ],
#     updated_at=1764937947675,
#     updated_by='e04058ec-8264-440d-a49d-25b31ac1b9ca'
# )
# RecipientInfo(
#     activated=None,
#     activation_url=None,
#     authentication_type=<AuthenticationType.TOKEN: 'TOKEN'>,
#     cloud=None,
#     comment=None,
#     created_at=1764805057651,
#     created_by='ntnkshv_edaas_outlook.com#ext#@ntnkshvedaasoutlook.onmicrosoft.com',
#     data_recipient_global_metastore_id=None,
#     expiration_time=None,
#     ip_access_list=None,
#     metastore_id=None,
#     name='tech',
#     owner='ntnkshv_edaas_outlook.com#ext#@ntnkshvedaasoutlook.onmicrosoft.com',
#     properties_kvpairs=SecurablePropertiesKvPairs(properties={'databricks.name': 'tech'}),
#     region=None,
#     sharing_code=None,
#     tokens=[
#         RecipientTokenInfo(
#             activation_url='https://australiaeast.azuredatabricks.net/delta_sharing/retrieve_config.html?MpflqoeHfD
# ddOrguhPAYWEVUb1NRQd09B0LoJFuITfcVFmYgXHe6FKQ9eV-zv1Qj',
#             created_at=1764805057656,
#             created_by='ntnkshv_edaas_outlook.com#ext#@ntnkshvedaasoutlook.onmicrosoft.com',
#             expiration_time=1772581057658,
#             id='ef701349-9076-43d2-81df-d4d958a7eb62',
#             updated_at=1764805057658,
#             updated_by='ntnkshv_edaas_outlook.com#ext#@ntnkshvedaasoutlook.onmicrosoft.com'
#         )
#     ],
#     updated_at=1764805057651,
#     updated_by='ntnkshv_edaas_outlook.com#ext#@ntnkshvedaasoutlook.onmicrosoft.com'
# )
# RecipientInfo(
#     activated=None,
#     activation_url=None,
#     authentication_type=<AuthenticationType.TOKEN: 'TOKEN'>,
#     cloud=None,
#     comment='this is for pam businessline',
#     created_at=1765090544438,
#     created_by='e04058ec-8264-440d-a49d-25b31ac1b9ca',
#     data_recipient_global_metastore_id=None,
#     expiration_time=None,
#     ip_access_list=None,
#     metastore_id=None,
#     name='testing_pam',
#     owner='account users',
#     properties_kvpairs=SecurablePropertiesKvPairs(properties={'databricks.name': 'testing_pam'}),
#     region=None,
#     sharing_code=None,
#     tokens=[
#         RecipientTokenInfo(
#             activation_url='https://australiaeast.azuredatabricks.net/delta_sharing/retrieve_config.html?1tsFv2Ka4p
# tKj1D2MnHUfNPkQ0eArsdThmi2g60wr4bG1Qzl-_1L1YcWcaNSF8hr',
#             created_at=1765440641125,
#             created_by='e04058ec-8264-440d-a49d-25b31ac1b9ca',
#             expiration_time=1773216641128,
#             id='d156a524-6ad9-4863-b0ab-fc16825ec234',
#             updated_at=1765440641128,
#             updated_by='e04058ec-8264-440d-a49d-25b31ac1b9ca'
#         )
#     ],
#     updated_at=1765161214292,
#     updated_by='ntnkshv_edaas_outlook.com#ext#@ntnkshvedaasoutlook.onmicrosoft.com'
# )
# RecipientInfo(
#     activated=None,
#     activation_url=None,
#     authentication_type=<AuthenticationType.DATABRICKS: 'DATABRICKS'>,
#     cloud='aws',
#     comment=None,
#     created_at=1764796883665,
#     created_by='ntnkshv_edaas_outlook.com#ext#@ntnkshvedaasoutlook.onmicrosoft.com',
#     data_recipient_global_metastore_id='aws:us-east-2:3d9594c6-a8ee-43eb-8eea-f9d34d210a08',
#     expiration_time=None,
#     ip_access_list=None,
#     metastore_id='3d9594c6-a8ee-43eb-8eea-f9d34d210a08',
#     name='wd_test',
#     owner='ntnkshv_edaas_outlook.com#ext#@ntnkshvedaasoutlook.onmicrosoft.com',
#     properties_kvpairs=SecurablePropertiesKvPairs(
#         properties={
#             'databricks.name': 'wd_test',
#             'databricks.accountId': 'c0eee6d5-421e-4ae0-83d7-d78f1ce0f430',
#             'databricks.metastoreId': '3d9594c6-a8ee-43eb-8eea-f9d34d210a08'
#         }
#     ),
#     region='us-east-2',
#     sharing_code=None,
#     tokens=[],
#     updated_at=1764796883665,
#     updated_by='ntnkshv_edaas_outlook.com#ext#@ntnkshvedaasoutlook.onmicrosoft.com'
# )

# %%
## D2D recipient

import time
from databricks.sdk import WorkspaceClient
from databricks.sdk.service.sharing import AuthenticationType

# https://databricks-sdk-py.readthedocs.io/en/stable/workspace/sharing/recipients.html

w = WorkspaceClient(host="https://adb-2329622552520735.15.azuredatabricks.net/", token=access_token)

sharing_code = None


created = w.recipients.create(
    name=f"sdk-client-{time.time_ns()}",
    data_recipient_global_metastore_id="aws:us-west-2:a5895d0c-1436-4d8c-90eb-5a03b0f621fd",
    comment="This is recipient for delta sharing activity",
    authentication_type=AuthenticationType.DATABRICKS,
    sharing_code=sharing_code,
)

# Display recipient details
print(f"Name: {created.name}")
print(f"Activation URL: {created.activation_url}")
print(f"Region: {created.region}")
print(f"Sharing Code: {created.sharing_code}")
print(f"Tokens: {created.tokens}")
print(f"Updated At: {created.updated_at}")
# Out:
# Name: sdk-client-1764802372211690997
# Activation URL: None
# Region: us-west-2
# Sharing Code: None
# Tokens: []
# Updated At: 1764802373988

# %%
import time
from databricks.sdk import WorkspaceClient
from databricks.sdk.service.sharing import AuthenticationType

# https://databricks-sdk-py.readthedocs.io/en/stable/workspace/sharing/recipients.html

w = WorkspaceClient(host="https://adb-2329622552520735.15.azuredatabricks.net/", token=access_token)


w.recipients.delete(name="testing_pam")
# Out:
# ---------------------------------------------------------------------------
# NotFound                                  Traceback (most recent call last)
# Cell In[7], line 12
#       4 #https://databricks-sdk-py.readthedocs.io/en/stable/workspace/sharing/recipients.html
#       6 w = WorkspaceClient(
#       7   host  = 'https://adb-2329622552520735.15.azuredatabricks.net/',
#       8   token = access_token
#       9 )
# ---> 12 w.recipients.delete(name="testing_pam")
#
# File ~/.pyenv/versions/3.12.11/lib/python3.12/site-packages/databricks/sdk/service/sharing.py:3107, in RecipientsAPI.delete(self, name)
#    3097 """Deletes the specified recipient from the metastore. The caller must be the owner of the recipient.
#    3098
#    3099 :param name: str
#    (...)   3102
#    3103 """
#    3105 headers = {}
# -> 3107 self._api.do("DELETE", f"/api/2.1/unity-catalog/recipients/{name}", headers=headers)
#
# File ~/.pyenv/versions/3.12.11/lib/python3.12/site-packages/databricks/sdk/core.py:85, in ApiClient.do(self, method, path, url, query, headers, body, raw, files, data, auth, response_headers)
#      83     path = re.sub("^/api/2.0/fs/files//", "/api/2.0/fs/files/", path)
#      84     url = f"{self._cfg.host}{path}"
# ---> 85 return self._api_client.do(
#      86     method=method,
#      87     url=url,
#      88     query=query,
#      89     headers=headers,
#      90     body=body,
#      91     raw=raw,
#      92     files=files,
#      93     data=data,
#      94     auth=auth,
#      95     response_headers=response_headers,
#      96 )
#
# File ~/.pyenv/versions/3.12.11/lib/python3.12/site-packages/databricks/sdk/_base_client.py:196, in _BaseClient.do(self, method, url, query, headers, body, raw, files, data, auth, response_headers)
#     193     logger.debug(f"Retry disabled for non-seekable stream: type={type(data)}")
#     194     call = self._perform
# --> 196 response = call(
#     197     method,
#     198     url,
#     199     query=query,
#     200     headers=headers,
#     201     body=body,
#     202     raw=raw,
#     203     files=files,
#     204     data=data,
#     205     auth=auth,
#     206 )
#     208 resp = dict()
#     209 for header in response_headers if response_headers else []:
#
# File ~/.pyenv/versions/3.12.11/lib/python3.12/site-packages/databricks/sdk/retries.py:57, in retried.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#      53         retry_reason = f"{type(err).__name__} is allowed to retry"
#      55 if retry_reason is None:
#      56     # raise if exception is not retryable
# ---> 57     raise err
#      59 logger.debug(f"Retrying: {retry_reason} (sleeping ~{sleep}s)")
#      60 if before_retry:
#
# File ~/.pyenv/versions/3.12.11/lib/python3.12/site-packages/databricks/sdk/retries.py:36, in retried.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#      34 while clock.time() < deadline:
#      35     try:
# ---> 36         return func(*args, **kwargs)
#      37     except Exception as err:
#      38         last_err = err
#
# File ~/.pyenv/versions/3.12.11/lib/python3.12/site-packages/databricks/sdk/_base_client.py:298, in _BaseClient._perform(self, method, url, query, headers, body, raw, files, data, auth)
#     296 error = self._error_parser.get_api_error(response)
#     297 if error is not None:
# --> 298     raise error from None
#     300 return response
#
# NotFound: Recipient 'testing_pam' does not exist.

# %%
# D2O (Databricks to Open) - Token-based recipient

import time
from databricks.sdk import WorkspaceClient
from databricks.sdk.service.sharing import AuthenticationType, IpAccessList

w = WorkspaceClient(host="https://adb-2329622552520735.15.azuredatabricks.net/", token=access_token)

created = w.recipients.create(
    name=f"pam-client-{time.time_ns()}",
    comment="This is recipient for delta sharing activity",
    authentication_type=AuthenticationType.TOKEN,
    ip_access_list=IpAccessList(allowed_ip_addresses=["0.0.0.0/0", "212.212.3.0/24"]),
)

# Display recipient details
print(f"Name: {created.name}")
print(f"Activation URL: {created.activation_url}")
print(f"Region: {created.region}")
print(f"Sharing Code: {created.sharing_code}")
print(f"Tokens: {created.tokens}")
print(f"Updated At: {created.updated_at}")
# Out:
# Name: pam-client-1764805388466627073
# Activation URL: None
# Region: None
# Sharing Code: None
# Tokens:
# [RecipientTokenInfo(activation_url='https://australiaeast.azuredatabricks.net/delta_sharing/retrieve_config.html?4A
# kJEl63nSfby0FVmpSmvexFPyRdtvGVQPofXOQisUZakTicNX_wzof72dtKY9T9', created_at=1764805389934,
# created_by='e04058ec-8264-440d-a49d-25b31ac1b9ca', expiration_time=1772581389936,
# id='85f245c5-e0c5-4e22-94a6-ee369d89c073', updated_at=1764805389936,
# updated_by='e04058ec-8264-440d-a49d-25b31ac1b9ca')]
# Updated At: 1764805389927

# %%
## rotate token

import time
from databricks.sdk import WorkspaceClient
from databricks.sdk.service.sharing import AuthenticationType, IpAccessList

w = WorkspaceClient(host="https://adb-2329622552520735.15.azuredatabricks.net/", token=access_token)

created = w.recipients.rotate_token(name="pam-client-1764805388466627073", existing_token_expire_in_seconds=0)

print(f"Name: {created.name}")
print(f"Activation URL: {created.activation_url}")
print(f"Region: {created.region}")
print(f"Sharing Code: {created.sharing_code}")
print(f"Tokens: {created.tokens}")
print(f"Updated At: {created.updated_at}")
# Out:
# Name: pam-client-1764805388466627073
# Activation URL: None
# Region: None
# Sharing Code: None
# Tokens:
# [RecipientTokenInfo(activation_url='https://australiaeast.azuredatabricks.net/delta_sharing/retrieve_config.html?Ae
# BAm_i_A9s7qz_6bGijAR8qlpCPaIaagvTA03AGzf7jJ0CWXmMyD-EoHpv2S8Gh', created_at=1764806140511,
# created_by='e04058ec-8264-440d-a49d-25b31ac1b9ca', expiration_time=1772582140513,
# id='cc639cb1-6326-4195-8e94-d1774f525c02', updated_at=1764806140513,
# updated_by='e04058ec-8264-440d-a49d-25b31ac1b9ca')]
# Updated At: 1764805389927

# %%
import time
from databricks.sdk import WorkspaceClient
from databricks.sdk.service.sharing import AuthenticationType, IpAccessList

w = WorkspaceClient(host="https://adb-2329622552520735.15.azuredatabricks.net/", token=access_token)

ip_access_list = IpAccessList(allowed_ip_addresses=["1.1.1.2/0"])


w.recipients.update(
    name="pam-client-1764805388466627073", comment=f"sdk-{time.time_ns()}", ip_access_list=ip_access_list
)
# Out:
# RecipientInfo(activated=None, activation_url=None, authentication_type=<AuthenticationType.TOKEN: 'TOKEN'>, cloud=None, comment='sdk-1764808574404699743', created_at=1764805389927, created_by='e04058ec-8264-440d-a49d-25b31ac1b9ca', data_recipient_global_metastore_id=None, expiration_time=None, ip_access_list=IpAccessList(allowed_ip_addresses=['1.1.1.2/0']), metastore_id=None, name='pam-client-1764805388466627073', owner='e04058ec-8264-440d-a49d-25b31ac1b9ca', properties_kvpairs=SecurablePropertiesKvPairs(properties={'databricks.name': 'pam-client-1764805388466627073'}), region=None, sharing_code=None, tokens=[RecipientTokenInfo(activation_url=None, created_at=1764806140511, created_by='e04058ec-8264-440d-a49d-25b31ac1b9ca', expiration_time=1772582140513, id='cc639cb1-6326-4195-8e94-d1774f525c02', updated_at=1764806140513, updated_by='e04058ec-8264-440d-a49d-25b31ac1b9ca')], updated_at=1764808575183, updated_by='e04058ec-8264-440d-a49d-25b31ac1b9ca')

# %%
from databricks.sdk import WorkspaceClient

w = WorkspaceClient(host="https://adb-2329622552520735.15.azuredatabricks.net/", token=access_token)

# List all recipients
all_recipients = w.recipients.list()

for recipient in all_recipients:
    print(recipient)
# Out:
# RecipientInfo(
#     activated=None,
#     activation_url=None,
#     authentication_type=<AuthenticationType.DATABRICKS: 'DATABRICKS'>,
#     cloud='aws',
#     comment=None,
#     created_at=1764726522964,
#     created_by='ntnkshv_edaas_outlook.com#ext#@ntnkshvedaasoutlook.onmicrosoft.com',
#     data_recipient_global_metastore_id='aws:us-east-2:7b2005d1-3c82-4382-88ac-6cf31fd84712',
#     expiration_time=None,
#     ip_access_list=None,
#     metastore_id='7b2005d1-3c82-4382-88ac-6cf31fd84712',
#     name='aws_jllt',
#     owner='ntnkshv_edaas_outlook.com#ext#@ntnkshvedaasoutlook.onmicrosoft.com',
#     properties_kvpairs=SecurablePropertiesKvPairs(
#         properties={
#             'databricks.name': 'aws_jllt',
#             'databricks.accountId': 'c4ad19ae-0bc4-42ef-bc39-d355bc959b98',
#             'databricks.metastoreId': '7b2005d1-3c82-4382-88ac-6cf31fd84712'
#         }
#     ),
#     region='us-east-2',
#     sharing_code=None,
#     tokens=[],
#     updated_at=1764726522964,
#     updated_by='ntnkshv_edaas_outlook.com#ext#@ntnkshvedaasoutlook.onmicrosoft.com'
# )
# RecipientInfo(
#     activated=None,
#     activation_url=None,
#     authentication_type=<AuthenticationType.DATABRICKS: 'DATABRICKS'>,
#     cloud='aws',
#     comment=None,
#     created_at=1764221922020,
#     created_by='ntnkshv_edaas_outlook.com#ext#@ntnkshvedaasoutlook.onmicrosoft.com',
#     data_recipient_global_metastore_id='aws:us-west-2:b0924f6f-fd29-454e-b4a0-30031441e739',
#     expiration_time=None,
#     ip_access_list=None,
#     metastore_id='b0924f6f-fd29-454e-b4a0-30031441e739',
#     name='cmg_client',
#     owner='ntnkshv_edaas_outlook.com#ext#@ntnkshvedaasoutlook.onmicrosoft.com',
#     properties_kvpairs=SecurablePropertiesKvPairs(
#         properties={
#             'databricks.name': 'cmg_client',
#             'databricks.accountId': '72a0cb5c-2807-4c03-a01e-32a80bcf946e',
#             'databricks.metastoreId': 'b0924f6f-fd29-454e-b4a0-30031441e739'
#         }
#     ),
#     region='us-west-2',
#     sharing_code=None,
#     tokens=[],
#     updated_at=1764226371858,
#     updated_by='ntnkshv_edaas_outlook.com#ext#@ntnkshvedaasoutlook.onmicrosoft.com'
# )
# RecipientInfo(
#     activated=None,
#     activation_url=None,
#     authentication_type=<AuthenticationType.TOKEN: 'TOKEN'>,
#     cloud=None,
#     comment=None,
#     created_at=1764802666728,
#     created_by='ntnkshv_edaas_outlook.com#ext#@ntnkshvedaasoutlook.onmicrosoft.com',
#     data_recipient_global_metastore_id=None,
#     expiration_time=None,
#     ip_access_list=None,
#     metastore_id=None,
#     name='pam',
#     owner='ntnkshv_edaas_outlook.com#ext#@ntnkshvedaasoutlook.onmicrosoft.com',
#     properties_kvpairs=SecurablePropertiesKvPairs(properties={'databricks.name': 'pam'}),
#     region=None,
#     sharing_code=None,
#     tokens=[
#         RecipientTokenInfo(
#             activation_url=None,
#             created_at=1764804293067,
#             created_by='ntnkshv_edaas_outlook.com#ext#@ntnkshvedaasoutlook.onmicrosoft.com',
#             expiration_time=1764890767622,
#             id='04cb7dfb-345b-403a-ab5e-db5ed32551b6',
#             updated_at=1764804368622,
#             updated_by='ntnkshv_edaas_outlook.com#ext#@ntnkshvedaasoutlook.onmicrosoft.com'
#         )
#     ],
#     updated_at=1764804368640,
#     updated_by='ntnkshv_edaas_outlook.com#ext#@ntnkshvedaasoutlook.onmicrosoft.com'
# )
# RecipientInfo(
#     activated=None,
#     activation_url=None,
#     authentication_type=<AuthenticationType.TOKEN: 'TOKEN'>,
#     cloud=None,
#     comment='sdk-1764808574404699743',
#     created_at=1764805389927,
#     created_by='e04058ec-8264-440d-a49d-25b31ac1b9ca',
#     data_recipient_global_metastore_id=None,
#     expiration_time=None,
#     ip_access_list=IpAccessList(allowed_ip_addresses=['1.1.1.2/0']),
#     metastore_id=None,
#     name='pam-client-1764805388466627073',
#     owner='e04058ec-8264-440d-a49d-25b31ac1b9ca',
#     properties_kvpairs=SecurablePropertiesKvPairs(
#         properties={'databricks.name': 'pam-client-1764805388466627073'}
#     ),
#     region=None,
#     sharing_code=None,
#     tokens=[
#         RecipientTokenInfo(
#             activation_url=None,
#             created_at=1764806140511,
#             created_by='e04058ec-8264-440d-a49d-25b31ac1b9ca',
#             expiration_time=1772582140513,
#             id='cc639cb1-6326-4195-8e94-d1774f525c02',
#             updated_at=1764806140513,
#             updated_by='e04058ec-8264-440d-a49d-25b31ac1b9ca'
#         )
#     ],
#     updated_at=1764808575183,
#     updated_by='e04058ec-8264-440d-a49d-25b31ac1b9ca'
# )
# RecipientInfo(
#     activated=None,
#     activation_url=None,
#     authentication_type=<AuthenticationType.TOKEN: 'TOKEN'>,
#     cloud=None,
#     comment=None,
#     created_at=1764805057651,
#     created_by='ntnkshv_edaas_outlook.com#ext#@ntnkshvedaasoutlook.onmicrosoft.com',
#     data_recipient_global_metastore_id=None,
#     expiration_time=None,
#     ip_access_list=None,
#     metastore_id=None,
#     name='tech',
#     owner='ntnkshv_edaas_outlook.com#ext#@ntnkshvedaasoutlook.onmicrosoft.com',
#     properties_kvpairs=SecurablePropertiesKvPairs(properties={'databricks.name': 'tech'}),
#     region=None,
#     sharing_code=None,
#     tokens=[
#         RecipientTokenInfo(
#             activation_url='https://australiaeast.azuredatabricks.net/delta_sharing/retrieve_config.html?MpflqoeHfD
# ddOrguhPAYWEVUb1NRQd09B0LoJFuITfcVFmYgXHe6FKQ9eV-zv1Qj',
#             created_at=1764805057656,
#             created_by='ntnkshv_edaas_outlook.com#ext#@ntnkshvedaasoutlook.onmicrosoft.com',
#             expiration_time=1772581057658,
#             id='ef701349-9076-43d2-81df-d4d958a7eb62',
#             updated_at=1764805057658,
#             updated_by='ntnkshv_edaas_outlook.com#ext#@ntnkshvedaasoutlook.onmicrosoft.com'
#         )
#     ],
#     updated_at=1764805057651,
#     updated_by='ntnkshv_edaas_outlook.com#ext#@ntnkshvedaasoutlook.onmicrosoft.com'
# )
# RecipientInfo(
#     activated=None,
#     activation_url=None,
#     authentication_type=<AuthenticationType.DATABRICKS: 'DATABRICKS'>,
#     cloud='aws',
#     comment=None,
#     created_at=1764796883665,
#     created_by='ntnkshv_edaas_outlook.com#ext#@ntnkshvedaasoutlook.onmicrosoft.com',
#     data_recipient_global_metastore_id='aws:us-east-2:3d9594c6-a8ee-43eb-8eea-f9d34d210a08',
#     expiration_time=None,
#     ip_access_list=None,
#     metastore_id='3d9594c6-a8ee-43eb-8eea-f9d34d210a08',
#     name='wd_test',
#     owner='ntnkshv_edaas_outlook.com#ext#@ntnkshvedaasoutlook.onmicrosoft.com',
#     properties_kvpairs=SecurablePropertiesKvPairs(
#         properties={
#             'databricks.name': 'wd_test',
#             'databricks.accountId': 'c0eee6d5-421e-4ae0-83d7-d78f1ce0f430',
#             'databricks.metastoreId': '3d9594c6-a8ee-43eb-8eea-f9d34d210a08'
#         }
#     ),
#     region='us-east-2',
#     sharing_code=None,
#     tokens=[],
#     updated_at=1764796883665,
#     updated_by='ntnkshv_edaas_outlook.com#ext#@ntnkshvedaasoutlook.onmicrosoft.com'
# )
